# %%
import advertools as adv
import pandas as pd

# %%
crawl_df = pd.read_json("../output/crawl_output.jl", lines=True)
crawl_df
# Out:
#                                                     url  \
# 0                                   https://ahrefs.com/
# 1                              https://ahrefs.com/blog/
# 2                  https://ahrefs.com/keywords-explorer
# 3          https://ahrefs.com/academy/how-to-use-ahrefs
# 4                            https://ahrefs.com/academy
# ...                                                 ...
# 2002  https://app.ahrefs.com/academy/seo-training-co...
# 2003  https://app.ahrefs.com/academy/seo-training-co...
# 2004  https://app.ahrefs.com/academy/seo-training-co...
# 2005  https://app.ahrefs.com/academy/seo-training-co...
# 2006         https://ahrefs.com/blog/author/alex-dealy/
#
#                                                   title  \
# 0     Ahrefs - SEO Tools & Resources To Grow Your Se...
# 1           Ahrefs Blog | Get Better at SEO & Marketing
# 2     Keywords Explorer by Ahrefs: Discover Keyword ...
# 3                          How to use Ahrefs' SEO tools
# 4     Ahrefs Academy: Learn how to apply Ahrefs' too...
# ...                                                 ...
# 2002                                   Just a moment...
# 2003                                   Just a moment...
# 2004                                   Just a moment...
# 2005                                   Just a moment...
# 2006           Alex Dealy, Author at SEO Blog by Ahrefs
#
#                                               meta_desc  \
# 0     You don't have to be an SEO pro to rank higher...
# 1     We help you get better at SEO and marketing: d...
# 2     The most complete keyword research tool on the...
# 3     Learn how to use Ahrefs' SEO tools and reports...
# 4     Video tutorials that teach you how to rank hig...
# ...                                                 ...
# 2002                                                NaN
# 2003                                                NaN
# 2004                                                NaN
# 2005                                                NaN
# 2006           Alex Dealy, Author at SEO Blog by Ahrefs
#
#                                    viewport charset  \
# 0        width=device-width,initial-scale=1   utf-8
# 1     width=device-width, initial-scale=1.0   UTF-8
# 2        width=device-width,initial-scale=1   utf-8
# 3       width=device-width, initial-scale=1   utf-8
# 4        width=device-width,initial-scale=1   utf-8
# ...                                     ...     ...
# 2002     width=device-width,initial-scale=1     NaN
# 2003     width=device-width,initial-scale=1     NaN
# 2004     width=device-width,initial-scale=1     NaN
# 2005     width=device-width,initial-scale=1     NaN
# 2006  width=device-width, initial-scale=1.0   UTF-8
#
#                                                      h1  \
# 0     Everything you needto  rank higher& get more t...
# 1                                       The Ahrefs Blog
# 2                        Keywords Explorer@@Get started
# 3                          How to use Ahrefs@@Course by
# 4                                               Academy
# ...                                                 ...
# 2002                                                NaN
# 2003                                                NaN
# 2004                                                NaN
# 2005                                                NaN
# 2006                                         Alex Dealy
#
#                                                      h2                h4  \
# 0     All-in-oneSEO toolset @@Best in classSEO data ...  Rank@@Bot@@Owner
# 1      Search Intent in SEO: What It Is & How to Opt...               NaN
# 2     The most complete keyword research tool on the...               NaN
# 3     What you'll learn@@Course breakdown@@Ready to ...               NaN
# 4     How to use Ahrefs@@Ahrefs’ Certification Cours...               NaN
# ...                                                 ...               ...
# 2002                                                NaN               NaN
# 2003                                                NaN               NaN
# 2004                                                NaN               NaN
# 2005                                                NaN               NaN
# 2006               Most Recent Articles@@The Blog Squad               NaN
#
#                                          canonical  \
# 0                              https://ahrefs.com/
# 1                         https://ahrefs.com/blog/
# 2             https://ahrefs.com/keywords-explorer
# 3     https://ahrefs.com/academy/how-to-use-ahrefs
# 4                       https://ahrefs.com/academy
# ...                                            ...
# 2002                                           NaN
# 2003                                           NaN
# 2004                                           NaN
# 2005                                           NaN
# 2006    https://ahrefs.com/blog/author/alex-dealy/
#
#                                                alt_href  ...  \
# 0     https://ahrefs.com/@@https://ahrefs.com/de@@ht...  ...
# 1     https://ahrefs.com/blog/feed/@@https://ahrefs....  ...
# 2     https://ahrefs.com/keywords-explorer@@https://...  ...
# 3     https://ahrefs.com/academy/how-to-use-ahrefs@@...  ...
# 4     https://ahrefs.com/academy@@https://ahrefs.com...  ...
# ...                                                 ...  ...
# 2002                                                NaN  ...
# 2003                                                NaN  ...
# 2004                                                NaN  ...
# 2005                                                NaN  ...
# 2006  https://ahrefs.com/blog/feed/@@https://ahrefs....  ...
#
#      jsonld_1_description jsonld_1_contentUrl jsonld_1_potentialAction.@type  \
# 0                     NaN                 NaN                            NaN
# 1                     NaN                 NaN                            NaN
# 2                     NaN                 NaN                            NaN
# 3                     NaN                 NaN                            NaN
# 4                     NaN                 NaN                            NaN
# ...                   ...                 ...                            ...
# 2002                  NaN                 NaN                            NaN
# 2003                  NaN                 NaN                            NaN
# 2004                  NaN                 NaN                            NaN
# 2005                  NaN                 NaN                            NaN
# 2006                  NaN                 NaN                            NaN
#
#      jsonld_1_potentialAction.target  \
# 0                                NaN
# 1                                NaN
# 2                                NaN
# 3                                NaN
# 4                                NaN
# ...                              ...
# 2002                             NaN
# 2003                             NaN
# 2004                             NaN
# 2005                             NaN
# 2006                             NaN
#
#      jsonld_1_potentialAction.startOffset-input  \
# 0                                           NaN
# 1                                           NaN
# 2                                           NaN
# 3                                           NaN
# 4                                           NaN
# ...                                         ...
# 2002                                        NaN
# 2003                                        NaN
# 2004                                        NaN
# 2005                                        NaN
# 2006                                        NaN
#
#      resp_headers_access-control-allow-credentials resp_headers_etag  \
# 0                                              NaN               NaN
# 1                                              NaN               NaN
# 2                                              NaN               NaN
# 3                                              NaN               NaN
# 4                                              NaN               NaN
# ...                                            ...               ...
# 2002                                           NaN               NaN
# 2003                                           NaN               NaN
# 2004                                           NaN               NaN
# 2005                                           NaN               NaN
# 2006                                           NaN               NaN
#
#      resp_headers_x-dns-prefetch-control resp_headers_x-download-options  \
# 0                                    NaN                             NaN
# 1                                    NaN                             NaN
# 2                                    NaN                             NaN
# 3                                    NaN                             NaN
# 4                                    NaN                             NaN
# ...                                  ...                             ...
# 2002                                 NaN                             NaN
# 2003                                 NaN                             NaN
# 2004                                 NaN                             NaN
# 2005                                 NaN                             NaN
# 2006                                 NaN                             NaN
#
#      resp_headers_content-length
# 0                            NaN
# 1                            NaN
# 2                            NaN
# 3                            NaN
# 4                            NaN
# ...                          ...
# 2002                         NaN
# 2003                         NaN
# 2004                         NaN
# 2005                         NaN
# 2006                         NaN
#
# [2007 rows x 185 columns]

# %%
url_df = adv.url_to_df(crawl_df["url"])
url_df.to_csv("../output/url_data_ahrefs.csv")
